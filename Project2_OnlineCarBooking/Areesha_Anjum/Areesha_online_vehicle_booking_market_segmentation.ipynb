# %% [markdown]
# # Importing libraries

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset Description

# %%
df = pd.read_csv('/kaggle/input/rideshare/rideshare_kaggle.csv')

# %%
df.shape
# Out:
# (693071, 57)

# %%
df.head()
# Out:
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
#
#               datetime          timezone            source    destination  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square  North Station
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square  North Station
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square  North Station
# 3  2018-11-30 04:53:02  America/New_York  Haymarket Square  North Station
# 4  2018-11-29 03:49:20  America/New_York  Haymarket Square  North Station
#
#   cab_type  ... precipIntensityMax uvIndexTime  temperatureMin  \
# 0     Lyft  ...             0.1276  1544979600           39.89
# 1     Lyft  ...             0.1300  1543251600           40.49
# 2     Lyft  ...             0.1064  1543338000           35.36
# 3     Lyft  ...             0.0000  1543507200           34.67
# 4     Lyft  ...             0.0001  1543420800           33.10
#
#    temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 0          1545012000           43.68          1544968800
# 1          1543233600           47.30          1543251600
# 2          1543377600           47.55          1543320000
# 3          1543550400           45.03          1543510800
# 4          1543402800           42.18          1543420800
#
#    apparentTemperatureMin  apparentTemperatureMinTime  apparentTemperatureMax  \
# 0                   33.73                  1545012000                   38.07
# 1                   36.20                  1543291200                   43.92
# 2                   31.04                  1543377600                   44.12
# 3                   30.30                  1543550400                   38.53
# 4                   29.11                  1543392000                   35.75
#
#   apparentTemperatureMaxTime
# 0                 1544958000
# 1                 1543251600
# 2                 1543320000
# 3                 1543510800
# 4                 1543420800
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           693071 non-null  object
#  1   timestamp                    693071 non-null  float64
#  2   hour                         693071 non-null  int64
#  3   day                          693071 non-null  int64
#  4   month                        693071 non-null  int64
#  5   datetime                     693071 non-null  object
#  6   timezone                     693071 non-null  object
#  7   source                       693071 non-null  object
#  8   destination                  693071 non-null  object
#  9   cab_type                     693071 non-null  object
#  10  product_id                   693071 non-null  object
#  11  name                         693071 non-null  object
#  12  price                        637976 non-null  float64
#  13  distance                     693071 non-null  float64
#  14  surge_multiplier             693071 non-null  float64
#  15  latitude                     693071 non-null  float64
#  16  longitude                    693071 non-null  float64
#  17  temperature                  693071 non-null  float64
#  18  apparentTemperature          693071 non-null  float64
#  19  short_summary                693071 non-null  object
#  20  long_summary                 693071 non-null  object
#  21  precipIntensity              693071 non-null  float64
#  22  precipProbability            693071 non-null  float64
#  23  humidity                     693071 non-null  float64
#  24  windSpeed                    693071 non-null  float64
#  25  windGust                     693071 non-null  float64
#  26  windGustTime                 693071 non-null  int64
#  27  visibility                   693071 non-null  float64
#  28  temperatureHigh              693071 non-null  float64
#  29  temperatureHighTime          693071 non-null  int64
#  30  temperatureLow               693071 non-null  float64
#  31  temperatureLowTime           693071 non-null  int64
#  32  apparentTemperatureHigh      693071 non-null  float64
#  33  apparentTemperatureHighTime  693071 non-null  int64
#  34  apparentTemperatureLow       693071 non-null  float64
#  35  apparentTemperatureLowTime   693071 non-null  int64
#  36  icon                         693071 non-null  object
#  37  dewPoint                     693071 non-null  float64
#  38  pressure                     693071 non-null  float64
#  39  windBearing                  693071 non-null  int64
#  40  cloudCover                   693071 non-null  float64
#  41  uvIndex                      693071 non-null  int64
#  42  visibility.1                 693071 non-null  float64
#  43  ozone                        693071 non-null  float64
#  44  sunriseTime                  693071 non-null  int64
#  45  sunsetTime                   693071 non-null  int64
#  46  moonPhase                    693071 non-null  float64
#  47  precipIntensityMax           693071 non-null  float64
#  48  uvIndexTime                  693071 non-null  int64
#  49  temperatureMin               693071 non-null  float64
#  50  temperatureMinTime           693071 non-null  int64
#  51  temperatureMax               693071 non-null  float64
#  52  temperatureMaxTime           693071 non-null  int64
#  53  apparentTemperatureMin       693071 non-null  float64
#  54  apparentTemperatureMinTime   693071 non-null  int64
#  55  apparentTemperatureMax       693071 non-null  float64
#  56  apparentTemperatureMaxTime   693071 non-null  int64
# dtypes: float64(29), int64(17), object(11)
# memory usage: 301.4+ MB

# %% [markdown]
# # Exploratory Data Analysis

# %%
#selecting the appropriate features according to the problem statement
new_df = df[['hour', 'day', 'month', 'datetime', 'timezone', 'source', 'destination', 'cab_type', 'product_id', 'name', 'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature', 'short_summary', 'long_summary']]

# %%
new_df.shape
# Out:
# (693071, 17)

# %%
new_df.head()
# Out:
#    hour  day  month             datetime          timezone            source  \
# 0     9   16     12  2018-12-16 09:30:07  America/New_York  Haymarket Square
# 1     2   27     11  2018-11-27 02:00:23  America/New_York  Haymarket Square
# 2     1   28     11  2018-11-28 01:00:22  America/New_York  Haymarket Square
# 3     4   30     11  2018-11-30 04:53:02  America/New_York  Haymarket Square
# 4     3   29     11  2018-11-29 03:49:20  America/New_York  Haymarket Square
#
#      destination cab_type    product_id          name  distance  \
# 0  North Station     Lyft     lyft_line        Shared      0.44
# 1  North Station     Lyft  lyft_premier           Lux      0.44
# 2  North Station     Lyft          lyft          Lyft      0.44
# 3  North Station     Lyft   lyft_luxsuv  Lux Black XL      0.44
# 4  North Station     Lyft     lyft_plus       Lyft XL      0.44
#
#    surge_multiplier  latitude  longitude  temperature    short_summary  \
# 0               1.0   42.2148    -71.033        42.34   Mostly Cloudy
# 1               1.0   42.2148    -71.033        43.58            Rain
# 2               1.0   42.2148    -71.033        38.33           Clear
# 3               1.0   42.2148    -71.033        34.38           Clear
# 4               1.0   42.2148    -71.033        37.44   Partly Cloudy
#
#                                         long_summary
# 0                          Rain throughout the day.
# 1   Rain until morning, starting again in the eve...
# 2                        Light rain in the morning.
# 3                 Partly cloudy throughout the day.
# 4                 Mostly cloudy throughout the day.

# %%
new_df.tail()
#we have only 2018 data
# Out:
#         hour  day  month             datetime          timezone    source  \
# 693066    23    1     12  2018-12-01 23:53:05  America/New_York  West End
# 693067    23    1     12  2018-12-01 23:53:05  America/New_York  West End
# 693068    23    1     12  2018-12-01 23:53:05  America/New_York  West End
# 693069    23    1     12  2018-12-01 23:53:05  America/New_York  West End
# 693070    23    1     12  2018-12-01 23:53:05  America/New_York  West End
#
#        destination cab_type                            product_id       name  \
# 693066   North End     Uber  6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL
# 693067   North End     Uber  55c66225-fbe7-4fd5-9072-eab1ece5e23e      UberX
# 693068   North End     Uber  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a       Taxi
# 693069   North End     Uber  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV
# 693070   North End     Uber  997acbb5-e102-41e1-b155-9df7de0a73f2   UberPool
#
#         distance  surge_multiplier  latitude  longitude  temperature  \
# 693066       1.0               1.0   42.3519   -71.0643        37.05
# 693067       1.0               1.0   42.3519   -71.0643        37.05
# 693068       1.0               1.0   42.3519   -71.0643        37.05
# 693069       1.0               1.0   42.3519   -71.0643        37.05
# 693070       1.0               1.0   42.3519   -71.0643        37.05
#
#           short_summary                                long_summary
# 693066   Partly Cloudy    Light rain in the morning and overnight.
# 693067   Partly Cloudy    Light rain in the morning and overnight.
# 693068   Partly Cloudy    Light rain in the morning and overnight.
# 693069   Partly Cloudy    Light rain in the morning and overnight.
# 693070   Partly Cloudy    Light rain in the morning and overnight.

# %%
# extracting day name feature from datetime
new_df['datetime'] = pd.to_datetime(new_df['datetime'])
new_df['day_name'] = new_df['datetime'].dt.day_name()

# %%
# distribution plot of distance feature
sns.displot(new_df['distance'], kde = True)

# %%
# distribution plot of temperature feature
sns.displot(new_df['temperature'], kde = True)

# %%
# We will work on these attributes
data = new_df[['hour', 'day', 'month', 'day_name','source', 'destination', 'cab_type', 'name', 'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature', 'short_summary']]

# %%
data.head()
# Out:
#    hour  day  month   day_name            source    destination cab_type  \
# 0     9   16     12     Sunday  Haymarket Square  North Station     Lyft
# 1     2   27     11    Tuesday  Haymarket Square  North Station     Lyft
# 2     1   28     11  Wednesday  Haymarket Square  North Station     Lyft
# 3     4   30     11     Friday  Haymarket Square  North Station     Lyft
# 4     3   29     11   Thursday  Haymarket Square  North Station     Lyft
#
#            name  distance  surge_multiplier  latitude  longitude  temperature  \
# 0        Shared      0.44               1.0   42.2148    -71.033        42.34
# 1           Lux      0.44               1.0   42.2148    -71.033        43.58
# 2          Lyft      0.44               1.0   42.2148    -71.033        38.33
# 3  Lux Black XL      0.44               1.0   42.2148    -71.033        34.38
# 4       Lyft XL      0.44               1.0   42.2148    -71.033        37.44
#
#      short_summary
# 0   Mostly Cloudy
# 1            Rain
# 2           Clear
# 3           Clear
# 4   Partly Cloudy

# %%
sns.countplot(data = data, x = 'hour')
# most no of cabs are booked between 11pm to 12pm
# See a good amount of bookings from 10am to 6pm
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
sns.countplot(data = data, x = 'day')
#month end are busiest
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data = data, x = 'day_name')
# most no of cabs are on Monday and Tuesday
# Out:
# <Axes: xlabel='day_name', ylabel='count'>

# %%
sns.countplot(data = data, x = 'cab_type')
# Out:
# <Axes: xlabel='cab_type', ylabel='count'>

# %%
data[data['cab_type'] == 'Lyft']['name'].value_counts()
# Out:
# name
# Lux             51235
# Lyft            51235
# Lux Black XL    51235
# Lyft XL         51235
# Lux Black       51235
# Shared          51233
# Name: count, dtype: int64

# %%
data[data['cab_type'] == 'Uber']['name'].value_counts()
# Out:
# name
# UberXL       55096
# WAV          55096
# Black SUV    55096
# Black        55095
# Taxi         55095
# UberX        55094
# UberPool     55091
# Name: count, dtype: int64

# %%
sns.countplot(data = data, x = 'surge_multiplier')
# most of the cabs are booked with less surge multiplier
# as the cab prices increases booking decreases
# Out:
# <Axes: xlabel='surge_multiplier', ylabel='count'>

# %%
data['temperature_range'] = pd.cut(x = data['temperature'], bins = [18, 24, 31, 38, 45, 52, 58], labels = ['18-24', '25-31', '32-38','39-45','46-52','53-58'])

# %%
sns.countplot(data = data, x = 'temperature_range')
# most of the bookings is in 39-45 temperature range
# Out:
# <Axes: xlabel='temperature_range', ylabel='count'>

# %%
data['distance_range'] = pd.cut(x = data['distance'], bins = [0, 2, 5, 8], labels = ['0-2','3-5','6-8'])

# %%
sns.countplot(data = data, x = 'distance_range')
# Out:
# <Axes: xlabel='distance_range', ylabel='count'>

# %%
data.head()
# Out:
#    hour  day  month   day_name            source    destination cab_type  \
# 0     9   16     12     Sunday  Haymarket Square  North Station     Lyft
# 1     2   27     11    Tuesday  Haymarket Square  North Station     Lyft
# 2     1   28     11  Wednesday  Haymarket Square  North Station     Lyft
# 3     4   30     11     Friday  Haymarket Square  North Station     Lyft
# 4     3   29     11   Thursday  Haymarket Square  North Station     Lyft
#
#            name  distance  surge_multiplier  latitude  longitude  temperature  \
# 0        Shared      0.44               1.0   42.2148    -71.033        42.34
# 1           Lux      0.44               1.0   42.2148    -71.033        43.58
# 2          Lyft      0.44               1.0   42.2148    -71.033        38.33
# 3  Lux Black XL      0.44               1.0   42.2148    -71.033        34.38
# 4       Lyft XL      0.44               1.0   42.2148    -71.033        37.44
#
#      short_summary temperature_range distance_range
# 0   Mostly Cloudy              39-45            0-2
# 1            Rain              39-45            0-2
# 2           Clear              39-45            0-2
# 3           Clear              32-38            0-2
# 4   Partly Cloudy              32-38            0-2

# %%
sns.countplot(data = data, x = 'short_summary')
plt.xticks(rotation = 45)
plt.plot()
# Out:
# []

# %%
sns.countplot(data = data, x = 'surge_multiplier', hue = 'cab_type')
plt.xticks(rotation = 45)
plt.plot()
# Only Lyft cabs increased the surge_multiplier
# Out:
# []

# %% [markdown]
# # Inferences

# %% [markdown]
# 1. Busiest hours for cab bookings were 10AM-6AM and 11PM-12PM.
# 2. Month ends from 27-30th were busiest.
# 3. Most number of cabs were booked on Monday and Tuesday.
# 4. Less number of cabs were booked as the prices increased.
# 5. Customers preferred cabs for mid distance ranges.
# 6. Customers avoided cabs during rain and foggy weather.

# %% [markdown]
# # Segmentation

# %%
df1 = pd.read_csv('/kaggle/input/sigma-cabs/sigma_cabs_kaggle.csv')

# %%
df1.head()
# Out:
#        Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 0  T0005689460           6.77           B                    1.0
# 1  T0005689461          29.47           B                   10.0
# 2  T0005689464          41.58         NaN                   10.0
# 3  T0005689465          61.56           C                   10.0
# 4  T0005689467          54.95           C                   10.0
#
#    Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 0           2.42769                           A                A
# 1           2.78245                           B                A
# 2               NaN                         NaN                E
# 3               NaN                         NaN                A
# 4           3.03453                           B                A
#
#    Customer_Rating  Cancellation_Last_1Month  Var1  Var2  Var3  Gender  \
# 0          3.90500                         0  40.0    46    60  Female
# 1          3.45000                         0  38.0    56    78    Male
# 2          3.50125                         2   NaN    56    77    Male
# 3          3.45375                         0   NaN    52    74    Male
# 4          3.40250                         4  51.0    49   102    Male
#
#    Surge_Pricing_Type
# 0                   2
# 1                   2
# 2                   2
# 3                   3
# 4                   2

# %%
df1.shape
# Out:
# (131662, 14)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131662 entries, 0 to 131661
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Trip_ID                      131662 non-null  object
#  1   Trip_Distance                131662 non-null  float64
#  2   Type_of_Cab                  111452 non-null  object
#  3   Customer_Since_Months        125742 non-null  float64
#  4   Life_Style_Index             111469 non-null  float64
#  5   Confidence_Life_Style_Index  111469 non-null  object
#  6   Destination_Type             131662 non-null  object
#  7   Customer_Rating              131662 non-null  float64
#  8   Cancellation_Last_1Month     131662 non-null  int64
#  9   Var1                         60632 non-null   float64
#  10  Var2                         131662 non-null  int64
#  11  Var3                         131662 non-null  int64
#  12  Gender                       131662 non-null  object
#  13  Surge_Pricing_Type           131662 non-null  int64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 14.1+ MB

# %%
#dropping undesired attributes
data1 = df1.drop(['Trip_ID', 'Var1', 'Var2', 'Var3'], axis = 1)

# %%
data1.head()
# Out:
#    Trip_Distance Type_of_Cab  Customer_Since_Months  Life_Style_Index  \
# 0           6.77           B                    1.0           2.42769
# 1          29.47           B                   10.0           2.78245
# 2          41.58         NaN                   10.0               NaN
# 3          61.56           C                   10.0               NaN
# 4          54.95           C                   10.0           3.03453
#
#   Confidence_Life_Style_Index Destination_Type  Customer_Rating  \
# 0                           A                A          3.90500
# 1                           B                A          3.45000
# 2                         NaN                E          3.50125
# 3                         NaN                A          3.45375
# 4                           B                A          3.40250
#
#    Cancellation_Last_1Month  Gender  Surge_Pricing_Type
# 0                         0  Female                   2
# 1                         0    Male                   2
# 2                         2    Male                   2
# 3                         0    Male                   3
# 4                         4    Male                   2

# %%
data1.isna().sum()
# Out:
# Trip_Distance                      0
# Type_of_Cab                    20210
# Customer_Since_Months           5920
# Life_Style_Index               20193
# Confidence_Life_Style_Index    20193
# Destination_Type                   0
# Customer_Rating                    0
# Cancellation_Last_1Month           0
# Gender                             0
# Surge_Pricing_Type                 0
# dtype: int64

# %%
#dropping all the null values
data1 = data1.dropna(axis = 0)

# %%
data1.isna().sum()
# Out:
# Trip_Distance                  0
# Type_of_Cab                    0
# Customer_Since_Months          0
# Life_Style_Index               0
# Confidence_Life_Style_Index    0
# Destination_Type               0
# Customer_Rating                0
# Cancellation_Last_1Month       0
# Gender                         0
# Surge_Pricing_Type             0
# dtype: int64

# %%
data1.shape
# Out:
# (90052, 10)

# %%
cat_cols = []
for col in data1.columns:
    if data1[col].dtypes == 'object':
        cat_cols.append(col)

# %%
cat_cols
# Out:
# ['Type_of_Cab', 'Confidence_Life_Style_Index', 'Destination_Type', 'Gender']

# %%
num_cols = data1.columns.difference(cat_cols)

# %%
num_cols
# Out:
# Index(['Cancellation_Last_1Month', 'Customer_Rating', 'Customer_Since_Months',
#        'Life_Style_Index', 'Surge_Pricing_Type', 'Trip_Distance'],
#       dtype='object')

# %% [markdown]
# ## Data Pre-processing

# %%
data1_copy = data1.copy()

# %%
encoder = LabelEncoder()
for col in cat_cols:
    data1_copy[col] = encoder.fit_transform(data1[col])

# %%
data1_copy.head()
# Out:
#    Trip_Distance  Type_of_Cab  Customer_Since_Months  Life_Style_Index  \
# 0           6.77            1                    1.0           2.42769
# 1          29.47            1                   10.0           2.78245
# 4          54.95            2                   10.0           3.03453
# 6          29.72            4                   10.0           2.83958
# 7          18.44            1                    2.0           2.81871
#
#    Confidence_Life_Style_Index  Destination_Type  Customer_Rating  \
# 0                            0                 0           3.9050
# 1                            1                 0           3.4500
# 4                            1                 0           3.4025
# 6                            2                 1           2.9750
# 7                            1                 0           3.5825
#
#    Cancellation_Last_1Month  Gender  Surge_Pricing_Type
# 0                         0       0                   2
# 1                         0       1                   2
# 4                         4       1                   2
# 6                         1       1                   2
# 7                         0       1                   2

# %%
data1_scaled = pd.DataFrame()
scaler = StandardScaler()
data1_scaled[data1_copy.columns] = scaler.fit_transform(data1_copy[data1_copy.columns])

# %%
data1_scaled.head()
# Out:
#    Trip_Distance  Type_of_Cab  Customer_Since_Months  Life_Style_Index  \
# 0      -1.479439    -0.570050              -1.381087         -1.726135
# 1      -0.591002    -0.570050               1.099971         -0.124347
# 2       0.406238     0.231207               1.099971          1.013828
# 3      -0.581218     1.833723               1.099971          0.133603
# 4      -1.022697    -0.570050              -1.105414          0.039372
#
#    Confidence_Life_Style_Index  Destination_Type  Customer_Rating  \
# 0                    -1.233471         -0.522602         1.076925
# 1                     0.000534         -0.522602         0.609733
# 2                     0.000534         -0.522602         0.560961
# 3                     1.234540         -0.000771         0.122006
# 4                     0.000534         -0.522602         0.745784
#
#    Cancellation_Last_1Month    Gender  Surge_Pricing_Type
# 0                 -0.754895 -1.573437           -0.208868
# 1                 -0.754895  0.635551           -0.208868
# 2                  3.085553  0.635551           -0.208868
# 3                  0.205217  0.635551           -0.208868
# 4                 -0.754895  0.635551           -0.208868

# %%
wcss = []
for cluster in range(1, 21):
    km = KMeans(n_clusters = cluster)
    km.fit_predict(data1_scaled)
    wcss.append(km.inertia_)

# %%
plt.figure(figsize = (8, 5))
plt.plot(range(1, 21), wcss, marker = 'o')
#there is no clear elbow point

# %% [markdown]
# # Segmentation Description

# %%
# Considering 4 clusters
km = KMeans(n_clusters = 4)
data1['Cluster'] = km.fit_predict(data1_scaled)

# %% [markdown]
# ## Segment0

# %%
segment0 = data1[data1['Cluster'] == 0]
segment0.shape
# Out:
# (23868, 11)

# %%
for col in cat_cols:
    print(segment0[col].value_counts()/len(segment0[col]))
#mostly covers the customers with destination_type = A
#average customer ratings between 2.5-3.7
#life_style_index between 2.8-3.2
#higher values of trip distance
# Out:
# Type_of_Cab
# C    0.281088
# B    0.279328
# A    0.172239
# D    0.165200
# E    0.102145
# Name: count, dtype: float64
# Confidence_Life_Style_Index
# B    0.489191
# C    0.480015
# A    0.030794
# Name: count, dtype: float64
# Destination_Type
# A    0.648316
# B    0.236216
# C    0.066072
# D    0.027778
# E    0.010809
# F    0.010223
# G    0.000461
# H    0.000126
# Name: count, dtype: float64
# Gender
# Male      0.71577
# Female    0.28423
# Name: count, dtype: float64

# %%
for col in num_cols:
    sns.displot(segment0[col])

# %% [markdown]
# ## Segment 1

# %%
segment1 = data1[data1['Cluster'] == 1]
segment1.shape
# Out:
# (29400, 11)

# %%
for col in cat_cols:
    print(segment1[col].value_counts()/len(segment1[col]))
# Out:
# Type_of_Cab
# C    0.335000
# D    0.317857
# E    0.197279
# B    0.111429
# A    0.038435
# Name: count, dtype: float64
# Confidence_Life_Style_Index
# C    0.404660
# B    0.364082
# A    0.231259
# Name: count, dtype: float64
# Destination_Type
# A    0.673401
# B    0.193061
# D    0.074082
# C    0.049524
# E    0.008741
# F    0.001190
# Name: count, dtype: float64
# Gender
# Male      0.709694
# Female    0.290306
# Name: count, dtype: float64

# %%
for col in num_cols:
    sns.displot(segment1[col])

# %% [markdown]
# # Segment 2

# %%
segment2 = data1[data1['Cluster'] == 2]
segment2.shape
# Out:
# (30927, 11)

# %%
for col in cat_cols:
    print(segment2[col].value_counts()/len(segment2[col]))
#mostly covers the customers with Confidence_Life_Style_Index = A
# Out:
# Type_of_Cab
# B    0.449154
# A    0.358069
# C    0.152941
# D    0.027128
# E    0.012707
# Name: count, dtype: float64
# Confidence_Life_Style_Index
# A    0.640023
# B    0.215184
# C    0.144793
# Name: count, dtype: float64
# Destination_Type
# A    0.578621
# B    0.286513
# C    0.065024
# D    0.048663
# E    0.019918
# F    0.001261
# Name: count, dtype: float64
# Gender
# Male      0.71187
# Female    0.28813
# Name: count, dtype: float64

# %%
for col in num_cols:
    sns.displot(segment2[col])

# %% [markdown]
# ## Segment 3

# %%
segment3 = data1[data1['Cluster'] == 3]
segment3.shape
# Out:
# (5857, 11)

# %%
for col in cat_cols:
    print(segment3[col].value_counts()/len(segment3[col]))
#This segment mostly overs customers with F,G,H,E as their destination type
#mostly covers customers with higher customer ratings between 3-5
#Long time customers with 10 months as their duration
# Out:
# Type_of_Cab
# B    0.243299
# C    0.239713
# D    0.200273
# A    0.186444
# E    0.130271
# Name: count, dtype: float64
# Confidence_Life_Style_Index
# A    0.385863
# B    0.320983
# C    0.293153
# Name: count, dtype: float64
# Destination_Type
# F    0.179614
# G    0.169711
# H    0.142735
# E    0.124808
# I    0.096978
# K    0.080929
# J    0.079392
# L    0.078026
# D    0.023732
# N    0.013317
# M    0.010756
# Name: count, dtype: float64
# Gender
# Male      0.713334
# Female    0.286666
# Name: count, dtype: float64

# %%
segment3[num_cols].describe()
# Out:
#        Cancellation_Last_1Month  Customer_Rating  Customer_Since_Months  \
# count               5857.000000      5857.000000            5857.000000
# mean                   0.970292         3.303557               5.043708
# std                    1.149575         1.001460               3.598459
# min                    0.000000         0.115000               0.000000
# 25%                    0.000000         2.611250               2.000000
# 50%                    1.000000         3.387500               5.000000
# 75%                    2.000000         4.092500               9.000000
# max                    8.000000         5.000000              10.000000
#
#        Life_Style_Index  Surge_Pricing_Type  Trip_Distance
# count       5857.000000         5857.000000    5857.000000
# mean           2.770117            2.250811      28.806314
# std            0.231070            0.735349      20.497935
# min            1.736560            1.000000       1.620000
# 25%            2.616930            2.000000      13.860000
# 50%            2.773780            2.000000      23.390000
# 75%            2.915400            3.000000      37.960000
# max            3.954620            3.000000     109.180000

# %%
for col in num_cols:
    sns.displot(segment3[col])
